# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import os
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
from skimage import io
from PIL import Image
# Out:
# 2024-02-02 22:41:18.905004: I tensorflow/core/platform/cpu_feature_guard.cc:183] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Avoid Out of Memory Error by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

gpus
# Out:
# 2024-02-02 22:41:21.317062: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-02 22:41:21.324955: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-02 22:41:21.325129: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# 2. Preprocess Data

# %% [markdown]
# 2.1 Augment Images

# %%
train_datagen = ImageDataGenerator(
    rotation_range=180,
    horizontal_flip=True,
    vertical_flip=True,
    width_shift_range=0.25,
    height_shift_range=0.25,
    shear_range=0.2,
    fill_mode='reflect',
)

# %%
# https://github.com/bnsreenu/python_for_microscopists/blob/master/127_data_augmentation_using_keras.py

for image_class in os.listdir('BM_cytomorphology_data_augmented'):
    dataset = []
    image_class_path = os.path.join('BM_cytomorphology_data_augmented', image_class)
    
    _, _, files = next(os.walk(image_class_path))
    number_files = len(files)

    images_needed = 25000 - number_files
        
    if images_needed > 0:
        print('Augmenting images for: ' + image_class)
        images = os.listdir(image_class_path)
        for i, image_name in enumerate(images):
            if not image_name.startswith('aug'):
                image_path = os.path.join(image_class_path, image_name)
                image = io.imread(image_path)
                image = Image.fromarray(image, 'RGB')
                dataset.append(np.array(image))
        
        x = np.array(dataset)

        for batch in train_datagen.flow(x, batch_size=64,  
                                        save_to_dir=image_class_path, 
                                        save_prefix='aug', 
                                        save_format='jpg'):
            
            _, _, files = next(os.walk(image_class_path))
            number_files = len(files)
            if (number_files >= 25000):
                print('Finished augmenting images for: ' + image_class)
                break

# %% [markdown]
# 2.1.1 Verify Number of Images

# %%
for image_class in os.listdir('BM_cytomorphology_data_augmented'):
    image_class_path = os.path.join('BM_cytomorphology_data_augmented', image_class)
    
    _, _, files = next(os.walk(image_class_path))
    number_files = len(files)
    
    print(f"{image_class}: {number_files} images")
# Out:
# EBO: 25006 images
# ART: 25057 images
# BLA: 25045 images
# NGB: 25018 images
# NIF: 25002 images
# MMZ: 25044 images
# HAC: 25061 images
# FGC: 25024 images
# OTH: 25027 images
# ABE: 25001 images
# PMO: 25017 images
# KSC: 25018 images
# MON: 25023 images
# EOS: 25046 images
# MYB: 25039 images
# PLM: 25011 images
# LYI: 25003 images
# LYT: 25000 images
# NGS: 25053 images
# PEB: 25004 images
# BAS: 25000 images

# %% [markdown]
# 2.2 Load Images

# %%
# Build data pipline
training_data = tf.keras.utils.image_dataset_from_directory('BM_cytomorphology_data_augmented', image_size=(250, 250))
val_data = tf.keras.utils.image_dataset_from_directory('Validation', image_size=(250, 250))
data_iterator = training_data.as_numpy_iterator()
batch = data_iterator.next()

label_to_class_mapping = {label: class_name for label, class_name in enumerate(training_data.class_names)}

label_to_class_mapping

numeric_labels = batch[1]

# Convert numeric labels to class names
class_names = [label_to_class_mapping[label] for label in numeric_labels]
# Out:
# Found 525499 files belonging to 21 classes.
# 2024-02-02 22:41:54.729405: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-02 22:41:54.729872: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-02 22:41:54.730242: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-02 22:41:54.821417: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-02 22:41:54.821583: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-02 22:41:54.821712: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-02 22:41:54.821823: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1638] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10135 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# Found 23973 files belonging to 21 classes.
# 2024-02-02 22:41:56.014955: I tensorflow/core/common_runtime/executor.cc:1209] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [525499]
# 	 [[{{node Placeholder/_4}}]]
# 2024-02-02 22:41:56.015426: I tensorflow/core/common_runtime/executor.cc:1209] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [525499]
# 	 [[{{node Placeholder/_4}}]]

# %% [markdown]
# 2.3 Scale Images

# %%
#Scale data from 0-255 to 0-1
training_data = training_data.map(lambda image,label: (image/255, label))
val_data = val_data.map(lambda image,label: (image/255, label))
scaled_iterator = training_data.as_numpy_iterator()
batch = scaled_iterator.next()
batch[0].max()
# data.as_numpy_iterator().next()[0].max()
# Out:
# 2024-02-02 22:41:56.266935: I tensorflow/core/common_runtime/executor.cc:1209] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [525499]
# 	 [[{{node Placeholder/_4}}]]
# 2024-02-02 22:41:56.267233: I tensorflow/core/common_runtime/executor.cc:1209] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [525499]
# 	 [[{{node Placeholder/_0}}]]
# 1.0

# %%
fig, ax = plt.subplots(ncols = 4, figsize=(20, 20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img)
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# 3. Deep Model

# %% [markdown]
# 3.1 Build Deep Learning Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization, Activation

model = Sequential()
# 16 filters, 3x3 size, stride of 1, 
#0
model.add(Conv2D(8, (3, 3), 1, input_shape=(250, 250, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))

#1
model.add(Conv2D(8, (3, 3), 1, padding='same'))  # Adjusted the kernel size
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(4, 4), strides=(4, 4)))

#2
model.add(Conv2D(16, (3, 3), 1, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))

#3
model.add(Conv2D(16, (3, 3), 1, padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(4, 4), strides=(4, 4)))

#4
model.add(Conv2D(32, (3, 3), 1, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))

#5
model.add(Conv2D(32, (3, 3), 1, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(4, 4), strides=(4, 4)))

#6
model.add(Conv2D(64, (3, 3), 1, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))

#7
model.add(Conv2D(64, (3, 3), 1, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(3, 3)))

model.add(Flatten())

# Fully connected layers
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dense(21))
model.add(Activation('softmax'))

# %%
# Uses adam optimiser
from tensorflow.keras.optimizers import Adam

# initial_learning_rate = 0.001
# optimizer = Adam(learning_rate=initial_learning_rate)

model.compile('adam', loss = tf.losses.SparseCategoricalCrossentropy(),metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 250, 250, 8)       224
#
#  batch_normalization (BatchN  (None, 250, 250, 8)      32
#  ormalization)
#
#  activation (Activation)     (None, 250, 250, 8)       0
#
#  conv2d_1 (Conv2D)           (None, 250, 250, 8)       584
#
#  activation_1 (Activation)   (None, 250, 250, 8)       0
#
#  max_pooling2d (MaxPooling2D  (None, 62, 62, 8)        0
#  )
#
#  conv2d_2 (Conv2D)           (None, 62, 62, 16)        1168
#
#  batch_normalization_1 (Batc  (None, 62, 62, 16)       64
#  hNormalization)
#
#  activation_2 (Activation)   (None, 62, 62, 16)        0
#
#  conv2d_3 (Conv2D)           (None, 62, 62, 16)        2320
#
#  activation_3 (Activation)   (None, 62, 62, 16)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 15, 15, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 15, 15, 32)        4640
#
#  batch_normalization_2 (Batc  (None, 15, 15, 32)       128
#  hNormalization)
#
#  activation_4 (Activation)   (None, 15, 15, 32)        0
#
#  conv2d_5 (Conv2D)           (None, 15, 15, 32)        9248
#
#  batch_normalization_3 (Batc  (None, 15, 15, 32)       128
#  hNormalization)
#
#  activation_5 (Activation)   (None, 15, 15, 32)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 3, 32)         0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 3, 3, 64)          18496
#
#  batch_normalization_4 (Batc  (None, 3, 3, 64)         256
#  hNormalization)
#
#  activation_6 (Activation)   (None, 3, 3, 64)          0
#
#  conv2d_7 (Conv2D)           (None, 3, 3, 64)          36928
#
#  batch_normalization_5 (Batc  (None, 3, 3, 64)         256
#  hNormalization)
#
#  activation_7 (Activation)   (None, 3, 3, 64)          0
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 256)               16640
#
#  activation_8 (Activation)   (None, 256)               0
#
#  dense_1 (Dense)             (None, 21)                5397
#
#  activation_9 (Activation)   (None, 21)                0
#
# =================================================================
# Total params: 96,509
# Trainable params: 96,077
# Non-trainable params: 432
# _________________________________________________________________

# %% [markdown]
# 3.2 Training

# %%
logdir = 'logs'
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = logdir)

# %%
import time

t0 = time.time()
hist = model.fit(training_data, epochs = 50, validation_data = val_data, callbacks = [tensorboard_callback], verbose = 2)
t1 = time.time()-t0

print('Training time: ', t1)
# Out:
# Epoch 1/50
# 2024-02-02 22:42:42.151388: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8901
# 2024-02-02 22:42:43.217874: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:655] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-02-02 22:42:43.319583: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x55c0fdad2890 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-02-02 22:42:43.319612: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2024-02-02 22:42:43.378558: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-02-02 22:42:43.968571: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2024-02-02 22:49:48.541312: I tensorflow/core/common_runtime/executor.cc:1209] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [23973]
# 	 [[{{node Placeholder/_0}}]]
# 2024-02-02 22:49:48.541736: I tensorflow/core/common_runtime/executor.cc:1209] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [23973]
# 	 [[{{node Placeholder/_0}}]]
# 16422/16422 - 443s - loss: 1.1533 - accuracy: 0.6282 - val_loss: 1.0558 - val_accuracy: 0.6542 - 443s/epoch - 27ms/step
# Epoch 2/50
# 16422/16422 - 433s - loss: 0.8314 - accuracy: 0.7259 - val_loss: 0.8272 - val_accuracy: 0.7327 - 433s/epoch - 26ms/step
# Epoch 3/50
# 16422/16422 - 425s - loss: 0.7498 - accuracy: 0.7508 - val_loss: 0.7604 - val_accuracy: 0.7523 - 425s/epoch - 26ms/step
# Epoch 4/50
# 16422/16422 - 430s - loss: 0.6998 - accuracy: 0.7665 - val_loss: 0.7467 - val_accuracy: 0.7528 - 430s/epoch - 26ms/step
# Epoch 5/50
# 16422/16422 - 426s - loss: 0.6657 - accuracy: 0.7776 - val_loss: 0.7214 - val_accuracy: 0.7649 - 426s/epoch - 26ms/step
# Epoch 6/50
# 16422/16422 - 430s - loss: 0.6417 - accuracy: 0.7846 - val_loss: 0.7181 - val_accuracy: 0.7650 - 430s/epoch - 26ms/step
# Epoch 7/50
# 16422/16422 - 431s - loss: 0.6210 - accuracy: 0.7922 - val_loss: 0.7320 - val_accuracy: 0.7619 - 431s/epoch - 26ms/step
# Epoch 8/50
# 16422/16422 - 432s - loss: 0.6052 - accuracy: 0.7963 - val_loss: 0.6724 - val_accuracy: 0.7789 - 432s/epoch - 26ms/step
# Epoch 9/50
# 16422/16422 - 431s - loss: 0.5907 - accuracy: 0.8017 - val_loss: 0.7156 - val_accuracy: 0.7664 - 431s/epoch - 26ms/step
# Epoch 10/50
# 16422/16422 - 430s - loss: 0.5793 - accuracy: 0.8051 - val_loss: 0.7622 - val_accuracy: 0.7557 - 430s/epoch - 26ms/step
# Epoch 11/50
# 16422/16422 - 432s - loss: 0.5687 - accuracy: 0.8080 - val_loss: 0.6816 - val_accuracy: 0.7763 - 432s/epoch - 26ms/step
# Epoch 12/50
# 16422/16422 - 429s - loss: 0.5595 - accuracy: 0.8108 - val_loss: 0.6925 - val_accuracy: 0.7762 - 429s/epoch - 26ms/step
# Epoch 13/50
# 16422/16422 - 432s - loss: 0.5524 - accuracy: 0.8136 - val_loss: 0.6937 - val_accuracy: 0.7723 - 432s/epoch - 26ms/step
# Epoch 14/50
# 16422/16422 - 430s - loss: 0.5442 - accuracy: 0.8156 - val_loss: 0.6861 - val_accuracy: 0.7777 - 430s/epoch - 26ms/step
# Epoch 15/50
# 16422/16422 - 429s - loss: 0.5383 - accuracy: 0.8179 - val_loss: 0.7198 - val_accuracy: 0.7671 - 429s/epoch - 26ms/step
# Epoch 16/50
# 16422/16422 - 431s - loss: 0.5310 - accuracy: 0.8202 - val_loss: 0.6688 - val_accuracy: 0.7843 - 431s/epoch - 26ms/step
# Epoch 17/50
# 16422/16422 - 429s - loss: 0.5270 - accuracy: 0.8216 - val_loss: 0.6567 - val_accuracy: 0.7864 - 429s/epoch - 26ms/step
# Epoch 18/50
# 16422/16422 - 425s - loss: 0.5207 - accuracy: 0.8230 - val_loss: 0.6877 - val_accuracy: 0.7766 - 425s/epoch - 26ms/step
# Epoch 19/50
# 16422/16422 - 431s - loss: 0.5171 - accuracy: 0.8245 - val_loss: 0.6530 - val_accuracy: 0.7876 - 431s/epoch - 26ms/step
# Epoch 20/50
# 16422/16422 - 429s - loss: 0.5126 - accuracy: 0.8258 - val_loss: 0.6813 - val_accuracy: 0.7754 - 429s/epoch - 26ms/step
# Epoch 21/50
# 16422/16422 - 431s - loss: 0.5077 - accuracy: 0.8273 - val_loss: 0.6544 - val_accuracy: 0.7906 - 431s/epoch - 26ms/step
# Epoch 22/50
# 16422/16422 - 431s - loss: 0.5042 - accuracy: 0.8280 - val_loss: 0.6579 - val_accuracy: 0.7886 - 431s/epoch - 26ms/step
# Epoch 23/50
# 16422/16422 - 429s - loss: 0.5004 - accuracy: 0.8293 - val_loss: 0.6817 - val_accuracy: 0.7827 - 429s/epoch - 26ms/step
# Epoch 24/50
# 16422/16422 - 430s - loss: 0.4965 - accuracy: 0.8305 - val_loss: 0.6454 - val_accuracy: 0.7906 - 430s/epoch - 26ms/step
# Epoch 25/50
# 16422/16422 - 429s - loss: 0.4933 - accuracy: 0.8316 - val_loss: 0.6740 - val_accuracy: 0.7863 - 429s/epoch - 26ms/step
# Epoch 26/50
# 16422/16422 - 425s - loss: 0.4909 - accuracy: 0.8327 - val_loss: 0.6405 - val_accuracy: 0.7959 - 425s/epoch - 26ms/step
# Epoch 27/50
# 16422/16422 - 428s - loss: 0.4883 - accuracy: 0.8329 - val_loss: 0.6430 - val_accuracy: 0.7939 - 428s/epoch - 26ms/step
# Epoch 28/50
# 16422/16422 - 429s - loss: 0.4847 - accuracy: 0.8344 - val_loss: 0.6440 - val_accuracy: 0.7928 - 429s/epoch - 26ms/step
# Epoch 29/50
# 16422/16422 - 426s - loss: 0.4825 - accuracy: 0.8349 - val_loss: 0.6698 - val_accuracy: 0.7866 - 426s/epoch - 26ms/step
# Epoch 30/50
# 16422/16422 - 431s - loss: 0.4795 - accuracy: 0.8359 - val_loss: 0.6624 - val_accuracy: 0.7890 - 431s/epoch - 26ms/step
# Epoch 31/50
# 16422/16422 - 428s - loss: 0.4773 - accuracy: 0.8364 - val_loss: 0.6446 - val_accuracy: 0.7951 - 428s/epoch - 26ms/step
# Epoch 32/50
# 16422/16422 - 426s - loss: 0.4765 - accuracy: 0.8369 - val_loss: 0.6996 - val_accuracy: 0.7753 - 426s/epoch - 26ms/step
# Epoch 33/50
# 16422/16422 - 430s - loss: 0.4727 - accuracy: 0.8378 - val_loss: 0.6463 - val_accuracy: 0.7939 - 430s/epoch - 26ms/step
# Epoch 34/50
# 16422/16422 - 425s - loss: 0.4711 - accuracy: 0.8384 - val_loss: 0.6622 - val_accuracy: 0.7921 - 425s/epoch - 26ms/step
# Epoch 35/50
# 16422/16422 - 425s - loss: 0.4689 - accuracy: 0.8391 - val_loss: 0.6584 - val_accuracy: 0.7919 - 425s/epoch - 26ms/step
# Epoch 36/50
# 16422/16422 - 427s - loss: 0.4668 - accuracy: 0.8399 - val_loss: 0.6447 - val_accuracy: 0.7939 - 427s/epoch - 26ms/step
# Epoch 37/50
# 16422/16422 - 428s - loss: 0.4653 - accuracy: 0.8403 - val_loss: 0.6698 - val_accuracy: 0.7896 - 428s/epoch - 26ms/step
# Epoch 38/50
# 16422/16422 - 432s - loss: 0.4648 - accuracy: 0.8402 - val_loss: 0.6509 - val_accuracy: 0.7940 - 432s/epoch - 26ms/step
# Epoch 39/50
# 16422/16422 - 429s - loss: 0.4614 - accuracy: 0.8419 - val_loss: 0.6470 - val_accuracy: 0.7953 - 429s/epoch - 26ms/step
# Epoch 40/50
# 16422/16422 - 426s - loss: 0.4599 - accuracy: 0.8417 - val_loss: 0.6438 - val_accuracy: 0.7946 - 426s/epoch - 26ms/step
# Epoch 41/50
# 16422/16422 - 423s - loss: 0.4593 - accuracy: 0.8419 - val_loss: 0.6398 - val_accuracy: 0.7986 - 423s/epoch - 26ms/step
# Epoch 42/50
# 16422/16422 - 424s - loss: 0.4579 - accuracy: 0.8428 - val_loss: 0.6526 - val_accuracy: 0.7939 - 424s/epoch - 26ms/step
# Epoch 43/50
# 16422/16422 - 425s - loss: 0.4551 - accuracy: 0.8429 - val_loss: 0.6364 - val_accuracy: 0.7983 - 425s/epoch - 26ms/step
# Epoch 44/50
# 16422/16422 - 427s - loss: 0.4547 - accuracy: 0.8439 - val_loss: 0.6647 - val_accuracy: 0.7933 - 427s/epoch - 26ms/step
# Epoch 45/50
# 16422/16422 - 431s - loss: 0.4529 - accuracy: 0.8439 - val_loss: 0.6799 - val_accuracy: 0.7900 - 431s/epoch - 26ms/step
# Epoch 46/50
# 16422/16422 - 432s - loss: 0.4519 - accuracy: 0.8442 - val_loss: 0.6522 - val_accuracy: 0.7948 - 432s/epoch - 26ms/step
# Epoch 47/50
# 16422/16422 - 428s - loss: 0.4499 - accuracy: 0.8455 - val_loss: 0.6483 - val_accuracy: 0.7994 - 428s/epoch - 26ms/step
# Epoch 48/50
# 16422/16422 - 427s - loss: 0.4486 - accuracy: 0.8456 - val_loss: 0.6411 - val_accuracy: 0.7981 - 427s/epoch - 26ms/step
# Epoch 49/50
# 16422/16422 - 432s - loss: 0.4475 - accuracy: 0.8457 - val_loss: 0.6486 - val_accuracy: 0.7963 - 432s/epoch - 26ms/step
# Epoch 50/50
# 16422/16422 - 433s - loss: 0.4459 - accuracy: 0.8462 - val_loss: 0.6556 - val_accuracy: 0.7951 - 433s/epoch - 26ms/step
# Training time:  21487.141169786453

# %% [markdown]
# 3.3 Plot Performance

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color = 'teal', label = 'loss')
plt.plot(hist.history['val_loss'], color = 'orange', label = 'val_loss')
fig.suptitle('Loss', fontsize = 20)
plt.legend(loc = "upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color = 'teal', label = 'accuracy')
plt.plot(hist.history['val_accuracy'], color = 'orange', label = 'val_accuracy')
fig.suptitle('Accuracy', fontsize = 20)
plt.legend(loc = "upper left")
plt.show()

# %%
import pickle

folder = 'pickle'
inner_foler = 'augmented_model'

with open(os.path.join(folder, inner_foler, 'model_pickle'), 'wb') as f:
    pickle.dump(model, f)

# %%
with open(os.path.join(folder, inner_foler, 'history_pickle'), 'wb') as f:
    pickle.dump(hist.history, f)

# %% [markdown]
# 4. Evaluate Performance

# %% [markdown]
# 4.1 Evaluate

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
precision_per_class = [tf.keras.metrics.Precision(class_id=i) for i in range(21)]
recall_per_class = [tf.keras.metrics.Recall(class_id=i) for i in range(21)]
accuracy_per_class = [tf.keras.metrics.BinaryAccuracy(threshold=0.0) for _ in range(21)]

# %%
y_true = []
y_pred = []

# batch_size = 16
# print("test")

for batch in val_data.as_numpy_iterator():
    batch_size = len(batch[0])  # Assuming the first element of the batch is the input data
    print(f"Current batch size: {batch_size}")
    image, y = batch
    y_one_hot = tf.one_hot(y, 21)
    yhat = model.predict(image)
    pre.update_state(y_one_hot, yhat)
    re.update_state(y_one_hot, yhat)
    acc.update_state(y_one_hot, yhat)
    
    y_true.extend(np.argmax(y_one_hot, axis = 1))
    y_pred.extend(np.argmax(yhat, axis = 1))
    
    # Had OOM errors previously
    tf.keras.backend.clear_session()
# Out:
# Current batch size: 32
# 1/1 [==============================] - 0s 171ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 75ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 74ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 75ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 76ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 74ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 75ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 75ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 75ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 74ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 67ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 74ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 76ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 60ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 60ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 60ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 60ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 74ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 71ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 60ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 74ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 74ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 74ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 67ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 67ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 67ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 67ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 67ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 67ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 67ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 67ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 68ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 67ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 67ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 67ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 67ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 68ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 68ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 67ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 76ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 68ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 67ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 75ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 67ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 77ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 68ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 74ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 67ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 60ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 69ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 75ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 74ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 74ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 60ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 74ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 74ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 60ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 74ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 60ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 66ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 60ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 60ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 74ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 76ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 75ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 75ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 60ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 73ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 76ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 74ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 77ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 75ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 72ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 74ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 60ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 74ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 64ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 74ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 63ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 62ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 61ms/step
# Current batch size: 32
# 1/1 [==============================] - 0s 65ms/step
# Current batch size: 5
# 1/1 [==============================] - 0s 130ms/step

# %%
from sklearn.metrics import classification_report

print("Total")
print(f'Precision{pre.result().numpy()}, Recall:{re.result().numpy()}, Accuracy:{acc.result().numpy()}')

y_true = np.array(y_true)
y_pred = np.array(y_pred)
class_labels = [str(i) for i in range(21)]
class_names = [label_to_class_mapping[label] for label in sorted(label_to_class_mapping.keys())]

# Generate classification report with specified labels
class_report = classification_report(y_true, y_pred, labels=class_labels, target_names=class_names)
print("Classification Report:\n", class_report)
# Out:
# Total
# Precision0.8313405513763428, Recall:0.7656947374343872, Accuracy:0.9814453721046448
# Classification Report:
#                precision    recall  f1-score   support
#
#          ABE       0.00      0.00      0.00         1
#          ART       0.82      0.84      0.83      2747
#          BAS       0.53      0.48      0.50        61
#          BLA       0.72      0.76      0.74      1675
#          EBO       0.90      0.90      0.90      3834
#          EOS       0.91      0.91      0.91       822
#          FGC       0.08      0.33      0.13         6
#          HAC       0.41      0.51      0.46        57
#          KSC       0.10      0.17      0.12         6
#          LYI       0.12      0.11      0.12         9
#          LYT       0.84      0.87      0.86      3673
#          MMZ       0.38      0.42      0.40       427
#          MON       0.61      0.61      0.61       564
#          MYB       0.63      0.55      0.59       917
#          NGB       0.60      0.65      0.62      1394
#          NGS       0.89      0.83      0.86      4118
#          NIF       0.52      0.38      0.44       494
#          OTH       0.57      0.51      0.54        41
#          PEB       0.61      0.79      0.68       382
#          PLM       0.86      0.78      0.82      1067
#          PMO       0.78      0.78      0.78      1678
#
#    micro avg       0.80      0.80      0.80     23973
#    macro avg       0.57      0.58      0.57     23973
# weighted avg       0.80      0.80      0.80     23973

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

true_labels = np.argmax(y_one_hot, axis=1)
predicted_labels = np.argmax(yhat, axis=1)
conf_matrix = confusion_matrix(y_true, y_pred, labels = list(range(21)))
plt.figure(figsize=(12, 9))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

confusion_data = {
    'conf_matrix': conf_matrix,
    'class_labels': class_names,
}

# %%
class_totals = np.sum(conf_matrix, axis=1)

normalised_conf_matrix = np.zeros_like(conf_matrix, dtype=float)
for i in range(len(class_totals)):
    if class_totals[i] != 0:
        normalised_conf_matrix[i, :] = np.round(conf_matrix[i, :] / class_totals[i], 2)

# # Plot the normalised confusion matrix with class names as tick labels
plt.figure(figsize=(12, 9))
sns.heatmap(normalised_conf_matrix, annot=True, fmt='.2f', cmap='Reds', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Normalised Confusion Matrix')
plt.show()

totals = np.sum(normalised_conf_matrix, axis=1)

normalised_confusion_data = {
    'normalised_conf_matrix': normalised_conf_matrix,
    'class_labels': class_names,
}

totals
# Out:
# array([1.  , 0.99, 1.01, 1.  , 0.98, 0.97, 0.99, 1.01, 1.  , 1.  , 0.97,
#        0.98, 1.  , 0.99, 1.  , 1.  , 0.99, 0.99, 0.99, 0.99, 0.99])

# %% [markdown]
# 5. Save model & outputs

# %%
with open(os.path.join(folder, inner_foler, 'classification_report'), 'wb') as f:
    pickle.dump(class_report, f)
    
with open(os.path.join(folder, inner_foler, 'confusion_data'), 'wb') as f:
    pickle.dump(confusion_data, f)
    
with open(os.path.join(folder, inner_foler, 'normalised_confusion_data'), 'wb') as f:
    pickle.dump(normalised_confusion_data, f)
