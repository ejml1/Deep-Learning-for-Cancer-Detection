# %%
import os
import pickle

folder = 'pickle'

with open(os.path.join(folder, 'model_pickle'), 'rb') as f:
    model = pickle.load(f)
    
with open(os.path.join(folder, 'history_pickle'), 'rb') as f:
    loaded_history = pickle.load(f)
# Out:
# 2024-01-15 15:01:29.758871: I tensorflow/core/platform/cpu_feature_guard.cc:183] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-15 15:01:31.536548: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-15 15:01:31.547831: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-15 15:01:31.548044: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-15 15:01:31.548881: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-15 15:01:31.549072: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-15 15:01:31.549232: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-15 15:01:31.625524: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-15 15:01:31.625694: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-15 15:01:31.625826: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-15 15:01:31.625936: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1638] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8977 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %% [markdown]
# Load Data

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
plt.plot(loaded_history['loss'], color='teal', label='loss')
plt.plot(loaded_history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(loaded_history['accuracy'], color='teal', label='accuracy')
plt.plot(loaded_history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
with open(os.path.join(folder, 'confusion_data'), 'rb') as f:
    loaded_confusion_data = pickle.load(f)

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

loaded_conf_matrix = loaded_confusion_data['conf_matrix']

# Access the class labels
class_names = loaded_confusion_data['class_labels']

plt.figure(figsize=(12, 9))
sns.heatmap(loaded_conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
with open(os.path.join(folder,'normalised_confusion_data'), 'rb') as f:
    loaded_confusion_data = pickle.load(f)

loaded_normalised_conf_matrix = loaded_confusion_data['normalised_conf_matrix']
    
plt.figure(figsize=(12, 9))
sns.heatmap(loaded_normalised_conf_matrix, annot=True, fmt='.2f', cmap='Reds', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Normalised Confusion Matrix')
plt.show()

# %%
with open(os.path.join(folder,'classification_report'), 'rb') as f:
    loaded_class_report = pickle.load(f)

# classification_report = loaded_class_report['class_report']

print("Classification Report:\n", loaded_class_report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#          ABE       0.00      0.00      0.00         2
#          ART       0.80      0.83      0.81      1972
#          BAS       0.12      0.14      0.13        42
#          BLA       0.63      0.70      0.66      1211
#          EBO       0.90      0.90      0.90      2746
#          EOS       0.88      0.85      0.87       592
#          FGC       0.00      0.00      0.00         7
#          HAC       0.24      0.21      0.22        47
#          KSC       1.00      0.50      0.67         2
#          LYI       0.00      0.00      0.00         8
#          LYT       0.81      0.85      0.83      2577
#          MMZ       0.26      0.36      0.30       299
#          MON       0.46      0.52      0.49       405
#          MYB       0.53      0.56      0.54       618
#          NGB       0.59      0.56      0.57      1042
#          NGS       0.84      0.83      0.84      2894
#          NIF       0.44      0.40      0.42       355
#          OTH       0.22      0.05      0.09        37
#          PEB       0.66      0.57      0.61       266
#          PLM       0.77      0.77      0.77       781
#          PMO       0.81      0.61      0.70      1189
#
#    micro avg       0.76      0.76      0.76     17092
#    macro avg       0.52      0.49      0.50     17092
# weighted avg       0.76      0.76      0.76     17092
